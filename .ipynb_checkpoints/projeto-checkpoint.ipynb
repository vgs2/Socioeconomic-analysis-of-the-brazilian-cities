# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df1 = pd.read_excel("PIB dos Municípios - base de dados 2002-2009.xls")
df2 = pd.read_csv('homicidios.csv', sep=';')

# %%
df1 = pd.read_excel("PIB dos Municípios - base de dados 2002-2009.xls")

# %%
df2 = pd.read_csv('homicidios.csv', sep=';')

# %%
df1[df1['Código do Município']==2611606]
# Out:
#         Ano  Código da Grande Região Nome da Grande Região  \
# 1593   2002                        2              Nordeste
# 7153   2003                        2              Nordeste
# 12713  2004                        2              Nordeste
# 18274  2005                        2              Nordeste
# 23838  2006                        2              Nordeste
# 29402  2007                        2              Nordeste
# 34966  2008                        2              Nordeste
# 40531  2009                        2              Nordeste
#
#        Código da Unidade da Federação Sigla da Unidade da Federação  \
# 1593                               26                            PE
# 7153                               26                            PE
# 12713                              26                            PE
# 18274                              26                            PE
# 23838                              26                            PE
# ...
